# %% [markdown]
# <a href="https://colab.research.google.com/github/sofisylab/SharkView/blob/main/notebooks/exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# SharkView - Data Exploration

print("SharkView iniciado 🦈")
# Out:
# SharkView iniciado 🦈
